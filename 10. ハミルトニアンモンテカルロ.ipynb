# %%
import numpy as np
from scipy.stats import norm, gamma
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use("ggplot")
np.random.seed(123)

# %%
k = 11
lam = 1
x = np.linspace(gamma.ppf(0.001, k), gamma.ppf(0.999, k), 100)
plt.plot(x, gamma.pdf(x, k, scale=1/lam))

# %%
f = lambda x, lam, k : -lam + (k - 1) / x

# %%
def leap_frog(q, p, eps, lam, k, f):
    p_new = p + 0.5 * eps * f(q, lam, k)
    q_new = q + eps * p_new
    p_new = p_new + 0.5 * eps * f(q_new, lam, k)
    q, p = q_new, p_new
    return q, p

# %%
eps = 1e-2
q, p = 4.0, 0.0
L = 100 # ハミルトニアン等高線上を遷移する回数
NMCS = 10000 # M-Hなら10万は必要
warmup = 5000

lf_arr = np.zeros([NMCS, 2])
n_accept = 0

for mcs in range(NMCS):
    hamiltonian_c = 0.5 * p ** 2 + lam * q - (k-1) * np.log(q)
    
    q_c, p_c = q, p
    for i in range(L):
        q_c, p_c = leap_frog(q_c, p_c, eps, lam, k, f)
    
    hamiltonian_new = 0.5 * p_c ** 2 + lam * q_c - (k-1) * np.log(q_c)
    
    # exp(H)とexp(H_new)の比で遷移
    # ハミルトニアンは等高線上でほぼ一定なので，遷移が起こる確率はほぼ１
    # この確率が数値計算の誤差によって変動してしまわないようにleap-frogを使った
    if np.random.rand() < np.exp(hamiltonian_c - hamiltonian_new):
        q, p = q_c, p_c
        hamiltonian_c = hamiltonian_new
        n_accept += 1
    lf_arr[mcs, :] = q, p
    p = norm.rvs()

df = pd.DataFrame(lf_arr[warmup:], columns=["q", "p"])
plt.figure(figsize=(9, 6))

# ハミルトニアン等高線を描く
x, y = np.linspace(0, 20, 100), np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
CS = plt.contour(X, Y, 0.5 * Y ** 2 - (k-1)*np.log(X)+lam * X, levels=[-12, -10, -5, 0])
plt.clabel(CS, inline=1, fontsize=10)

plt.scatter(df["q"][0], df["p"][0])
plt.scatter(df["q"], df["p"], marker=".", c=df.index, cmap="Blues") # c: color
plt.colorbar()
print("accept ratio: ", n_accept / NMCS)
# Out:
# d:\programming\python\bayes_stat_intro\.venv\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: divide by zero encountered in log
# accept ratio:  1.0

# %%
df["q"].hist(normed=True, bins=40)
x = np.linspace(gamma.ppf(0.001, k), gamma.ppf(0.999, k), 100)
plt.plot(x, gamma.pdf(x, k, scale=1/lam))
# Out:
# d:\programming\python\bayes_stat_intro\.venv\lib\site-packages\pandas\plotting\_core.py:2477: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)
